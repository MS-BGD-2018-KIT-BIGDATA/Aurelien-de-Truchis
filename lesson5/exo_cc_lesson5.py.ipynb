# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import seaborn as sns
# %matplotlib inline

# %%
med = pd.read_csv('med_gen.csv',  error_bad_lines=False,sep=';' )

# %%
med_regions = med[3:21]
# Out:
#     Unnamed: 0                   Type             DEPARTEMENT  EFFECTIF  \
# 3            3  01- Médecine générale  04- Alpes-Hte-Provence       159
# 4            4  01- Médecine générale        05- Hautes-Alpes       152
# 5            5  01- Médecine générale     06- Alpes-Maritimes      1166
# 6            6  01- Médecine générale             07- Ardèche       249
# 7            7  01- Médecine générale            08- Ardennes       231
# 8            8  01- Médecine générale              09- Ariège       139
# 9            9  01- Médecine générale                10- Aube       213
# 10          10  01- Médecine générale                11- Aude       337
# 11          11  01- Médecine générale             12- Aveyron       219
# 12          12  01- Médecine générale    13- Bouches-du-Rhône      2201
# 13          13  01- Médecine générale            14- Calvados       606
# 14          14  01- Médecine générale              15- Cantal       130
# 15          15  01- Médecine générale            16- Charente       263
# 16          16  01- Médecine générale   17- Charente-Maritime       591
# 17          17  01- Médecine générale                18- Cher       206
# 18          18  01- Médecine générale             19- Corrèze       174
# 19          19  01- Médecine générale        2A- Corse-du-Sud       131
# 20          20  01- Médecine générale         2B- Haute-Corse       144
#
#     POPULATION FRANCAISE  DENSITE /100 000 hab.  EFFECTIFS  \
# 3               162438.0              97.883500        159
# 4               141911.0             107.109385        152
# 5              1083268.0             107.637261       1166
# 6               321252.0              77.509245        249
# 7               281987.0              81.918670        231
# 8               152944.0              90.882938        139
# 9               306490.0              69.496558        213
# 10              367158.0              91.786098        337
# 11              275063.0              79.618124        219
# 12             1996351.0             110.251153       2201
# 13              690836.0              87.719806        606
# 14              146504.0              88.734779        130
# 15              354801.0              74.126059        263
# 16              635191.0              93.042880        591
# 17              312052.0              66.014639        206
# 18              239555.0              72.634677        174
# 19              148022.0              88.500358        131
# 20              175070.0              82.252813        144
#
#     HONORAIRES SANS DEPASSEMENT (Euros)  DEPASSEMENTS (Euros)  \
# 3                            22188985.0              101450.0
# 4                            19210311.0              259858.0
# 5                           143498917.0             6072337.0
# 6                            35248645.0              261064.0
# 7                            40134337.0               26064.0
# 8                            21090850.0               13848.0
# 9                            35968205.0              146094.0
# 10                           51766169.0              282717.0
# 11                           34180048.0              258034.0
# 12                          275268955.0             4077722.0
# 13                           88652950.0              946160.0
# 14                           19581011.0               48750.0
# 15                           39124144.0              127794.0
# 16                           81668712.0              306404.0
# 17                           31969332.0              281298.0
# 18                           25590987.0              119255.0
# 19                           18902984.0               67261.0
# 20                           20644260.0              149618.0
#
#     FRAIS DE DEPLACEMENT (Euros)  TOTAL DES HONORAIRES (Euros)
# 3                       341958.0                    22632393.0
# 4                       179646.0                    19649815.0
# 5                      1034885.0                   150606139.0
# 6                       260822.0                    35770531.0
# 7                       205338.0                    40365739.0
# 8                       350355.0                    21455053.0
# 9                       184931.0                    36299230.0
# 10                      410650.0                    52459536.0
# 11                      901356.0                    35339438.0
# 12                      150417.0                   279497094.0
# 13                      325360.0                    89924470.0
# 14                      785202.0                    20414963.0
# 15                      310685.0                    39562623.0
# 16                      482388.0                    82457504.0
# 17                      260464.0                    32511094.0
# 18                      628192.0                    26338434.0
# 19                     1010369.0                    19980614.0
# 20                     1243654.0                    22037532.0

# %%
import json
import os
state_geo = os.path.join('./france-geojson-master/departements-avec-outre-mer.geojson')
#state_unemployment = os.path.join('data', 'US_Unemployment_Oct2012.csv')
#state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48.856614, 2.352222], zoom_start=5)


m.choropleth(
    geo_data=state_geo,
    name='Densité de Médecin Généraliste par Département',
    data=newdata,
    columns=['Num_dep','Densite'],
    key_on='properties.code',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2
)


folium.LayerControl().add_to(m)
